# %% [markdown]
# ## Importar librerías

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2

# RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# KNeighborsRegressor
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# ## Exploración del Dataset

# %%
df = pd.read_csv("kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# Entender los atributos del dataset:
# - sqtf_living: pies cuadrados superficie
# - sqft_lot: superficie de la parcela en pies cuadrados (plot - parcela)
# - waterfront: acceso a agua
# - sqft_above: superficie en pies cuadrados arriba
# - sqft_basement: superficie sotano pies cuadrados
# - yr_built: año construcción
# - sqft_living15: pies cuadrados de los 15 vecinos más cercanos
# - sqft_lot15: pies cuadrados de las parcelas de los 15 vecinos más cercanos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# Comprobamos si tiene valores nulos.

df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df["price"].value_counts()
# Out:
# price
# 350000.0     172
# 450000.0     172
# 550000.0     159
# 500000.0     152
# 425000.0     150
#             ...
# 607010.0       1
# 1362500.0      1
# 298800.0       1
# 957500.0       1
# 402101.0       1
# Name: count, Length: 4028, dtype: int64

# %%
sns.displot(data=df, x="price")
# Out:
# C:\Users\bniet\.virtualenvs\Train_ML_Model-9EHOszp9\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Manipulación de datos

# %%
# Eliminación columnas 'id' y 'date'

df.drop(columns="id", inplace=True)
df.drop(columns="date", inplace=True)

df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
# ...

# %%
y = df["price"]
X = df.drop(columns="price")

# %% [markdown]
# El método .corr() en un DataFrame de Pandas se utiliza para calcular la correlación entre las columnas numéricas del DataFrame. La correlación es una medida estadística que indica la relación lineal entre dos variables. El valor de la correlación varía entre -1 y 1, donde -1 indica una correlación negativa perfecta, 0 indica que no hay correlación y 1 indica una correlación positiva perfecta.

# %%
corr = df.corr(method='pearson') # pearson: coeficiente de correlación estándar.
corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
# Si queremos ver la correlación de dos columnas en concreto. 
# La correlación más alta del precio de la vivienda es con la superficie de la casa. 
# Cuanto mayor superficie tiene la vivienda mayor es el precio de esta.
# Una correlación mayor a 0.7: se considera muy fuerte.

df.corr()['price']['sqft_living']
# Out:
# 0.7020350546118005

# %% [markdown]
# ## Preparación de los datos

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=42)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((17290, 18), (4323, 18), (17290,), (4323,))

# %% [markdown]
# ## Entrenamiento del modelo

# %% [markdown]
#  Error Absoluto Medio (MAE), el Error Cuadrático Medio (MSE), la Raíz del Error Cuadrático Medio (RMSE) y el Coeficiente de Determinación (R2)

# %% [markdown]
# ### LinearRegression

# %%
# Entrenamos el modelo con Regresión Lineal y generamos predicciones en la parte de train y test

model = LinearRegression()

model = model.fit(X_train, y_train)

# %%
# Esta función evalúa las principales métricas de problemas de regresión
def test(y_pred, y_true):
    train_mae = mae(y_true, y_pred)
    train_mse = mse(y_true, y_pred)
    train_rmse = np.sqrt(train_mse)
    train_r2 = r2(y_true, y_pred)
    
    
    print(f"MAE: {train_mae}")
    print(f"MSE: {train_mse}")
    print(f"RMSE: {train_rmse}")
    print(f"R2: {train_r2}")

# %%
# Esta función agrupa las dos anteriores para facilitar su uso
def pred_test(model, X_test, y_true):
    y_pred = model.predict(X_test)
    test(y_pred, y_true)

# %%
pred_test(model, X_train, y_train)
# Out:
# MAE: 125033.16493803971
# MSE: 39311882352.23279
# RMSE: 198272.24302012823
# R2: 0.6991021854487469

# %%
pred_test(model, X_test, y_test)
# Out:
# MAE: 127493.34208657486
# MSE: 45173046132.79021
# RMSE: 212539.51663817768
# R2: 0.7011904448878409

# %%
# Sin función para entenderlo y ver que coincide.
# Calcular MAE

y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

mae_train = mae(y_train, y_train_pred)
mae_test = mae(y_test, y_test_pred)

mae_train
# Out:
# 125033.16493803971

# %%
mae_test
# Out:
# 127493.34208657486

# %%
# Calcular MSE

mse_train = mse(y_train, y_train_pred)
mse_test = mse(y_test, y_test_pred)

mse_train
# Out:
# 39311882352.23279

# %%
mse_test
# Out:
# 45173046132.79021

# %%
# Calcular R2

r2_train = r2(y_train, y_train_pred)
r2_test = r2(y_test, y_test_pred)

r2_train
# Out:
# 0.6991021854487469

# %%
r2_test
# Out:
# 0.7011904448878409

# %% [markdown]
# ### KNeighborsRegressor

# %%
model = KNeighborsRegressor()

model = model.fit(X_train, y_train)

# %%
pred_test(model, X_train, y_train)
# Out:
# MAE: 126347.00459224985
# MSE: 42261372037.67482
# RMSE: 205575.70877337336
# R2: 0.676526441238916

# %%
pred_test(model, X_test, y_test)
# Out:
# MAE: 164904.38662965532
# MSE: 75023602754.92067
# RMSE: 273904.3679004055
# R2: 0.5037357167322707

# %% [markdown]
# ### RandomForestRegressor

# %%
# Entrenamos el modelo
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# Una vez entrenado el modelo, se evalúa la capacidad predictiva.

# %%
pred_test(model, X_train, y_train)
# Out:
# MAE: 25848.215968260167
# MSE: 2218238755.7929935
# RMSE: 47098.1820858618
# R2: 0.9830213372183362

# %%
pred_test(model, X_test, y_test)
# Out:
# MAE: 72750.43819332364
# MSE: 22076877993.514183
# RMSE: 148582.89939799326
# R2: 0.8539664101438819

# %% [markdown]
# Parece que hasta ahora este es el modelo con mayor eficacia.

# %% [markdown]
# En Random Forest no se produce overfitting por exceso de árboles. Sin embargo, añadir árboles una vez que la mejora se estabiliza es una perdida te recursos computacionales.

# %% [markdown]
#  ### AdaBoostClassifier

# %% [markdown]
# AdaBoost funciona eligiendo un algoritmo base (por ejemplo árboles de decisión) y mejorándolo.
# Se asignan pesos iguales a todos los ejemplos de entrenamiento y se elige un algoritmo base. En cada paso de iteración, sse aplica el algoritmo base al conjunto de entrenamiento y se aumenta los pesos de los ejemplos incorrectamente clasificados.

# %%
# Armando un simple arbol de decisión
tree = DecisionTreeClassifier(max_depth = 2, random_state = 0) # max_depth: niveles de profundidad del árbol
tree.fit(X_train, y_train)
print('Precisión modelo inicial train/test', tree.score(X_train, y_train),'/',tree.score(X_test, y_test))
print('Porcentaje precisión {0:.3f}/{1:.3f}'.format(tree.score(X_train, y_train), tree.score(X_test, y_test)))
# Out:
# Precisión modelo inicial train/test 0.014574898785425101 / 0.012953967152440436
# Porcentaje precisión 0.015/0.013

# %% [markdown]
# Ha tenido un rendimiento bastante malo, ya que tiene una precisión de 0.015% con los datos de entrenamiento y de 0.013% con los datos de evaluación.

# %%
# Utilizando AdaBoost sobre el mismo modelo para mejorar la precisión.
ada = AdaBoostClassifier(base_estimator=tree, n_estimators=100, learning_rate=1.5, random_state=1)

# Ajustando los datos
ada = ada.fit(X_train, y_train)
# Out:
# C:\Users\bniet\.virtualenvs\Train_ML_Model-9EHOszp9\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
